# %% [markdown]
# # Roster Change Decomposition (Scaffold)
#
# This notebook is a Phase 9 scaffold for the end-to-end roster-change analysis pipeline.

# %% [markdown]
# ## Pre-registered famous injury checks
# - McDavid (2019-02 knee)
# - Crosby (2011 concussion)
# - Matthews (2022-23 knee)
# - Stamkos (2013 tibia fracture)

# %%
# TODO: wire src/treatment_design.py, src/decomposition.py, and src/interaction_models.py once implemented.
EVENT_IDS = []
EVENT_IDS
